# %% [markdown]
# # 12: Synthesis and Recommendation
#
# **Business question, revisited**: Is Malaysia's AI data centre boom generating real economic activity today, or is it still mostly a pipeline of commitments, and who is actually capturing value from it?

# %%
from IPython.display import Image
Image(filename='../outputs/figures/12_synthesis.png')

# %% [markdown]
# ## The answer: both, and the split is now clearer than when this project started
#
# This is genuinely both a real, fast-growing economic activity and a pipeline still running well ahead of realised demand, and this project's own numbers show exactly where the line between the two currently sits.
#
# **What is real today**: Malaysia's live data centre capacity grew over tenfold in six years (Notebook 2). TNB is already drawing 1.26GW of actual load, up sharply from a year earlier (Notebook 3). YTL Power's data centre segment earned a real, audited RM345.5 million profit before tax in FY2026 (Notebook 5). EcoWorld's land sale has already added measurable, quantified profit to its FY2027 guidance (Notebook 7). Contractors are recognising real revenue on signed, in-progress contracts (Notebook 6). Data centres overtook manufacturing as Malaysia's largest source of net FDI by 2024 (Notebook 1).
#
# **What remains a pipeline of commitments, not yet realised**: 85% of TNB's secured capacity is not yet drawing power (Notebook 3). Over $23 billion in hyperscaler pledges have no public disbursement data attached to them at all (Notebook 8). A widely-repeated Johor land-price statistic could not be independently verified (Notebook 7). And the entire pipeline itself has been quietly filtered by an undisclosed government policy for roughly two years, meaning even the "committed" figures already reflect active curation, not raw market demand (Notebook 3).

# %% [markdown]
# ## Who is actually capturing value, restated plainly
#
# Ranked by how verifiable each layer's gain is today, not by how large the headline number is: **landowners and YTL Power** have the most concrete, already-realised financial gains; **contractors** have real revenue but margins that are ordinary for their industry, not the premium commonly assumed; **TNB** is spending real money and recovering it through real tariff increases, a slower-burn form of value capture; and **hyperscalers**, despite generating the largest headline dollar figures in every news story about this boom, are the layer this project could verify the least about, real pledges, but genuinely no visibility into what has actually been spent (Notebook 9).

# %% [markdown]
# ## Disclosed limitations, stated together rather than scattered
#
# This project deliberately did not resolve every ambiguity it found, and lists the most important ones here rather than only in the notebooks where they arose:
#
# - **No competitor benchmark exists for YTL Power's data centre segment specifically** (Notebook 5); this is a natural extension of the project, not a finished comparison.
# - **Order-book figures for IJM Corporation conflict across sources by date** and were not fully reconciled (Notebook 6); this project used the most recent consistent figure rather than averaging conflicting numbers.
# - **No disbursement-to-date data exists publicly for any hyperscaler pledge** (Notebook 8); the true scale of hyperscaler capital actually deployed in Malaysia cannot currently be measured from public information, by any researcher, not just this project.
# - **A widely-repeated Johor land-price trend figure could not be verified** to this project's sourcing standard and was deliberately excluded rather than passed through (Notebook 7).
# - **One claim about a multi-year pause in new gas-fired power capacity could not be verified** (a source fetch failed) and was excluded rather than assumed true (Notebook 11).
# - **TNB's own website prohibits reproduction of its content**; every TNB-originated figure in this project is cited to independent press pickups or government sources instead, following the same resolution pattern this portfolio used for a similar restriction in project 010 (Notebook 4).

# %% [markdown]
# ## Recommendation
#
# **Treat Malaysia's AI data centre boom as a genuine, fast-scaling economic activity that is still meaningfully ahead of its own realised demand, managed more deliberately by the government than headline coverage suggests, and unevenly distributed in who actually benefits from it today.** A business or investor evaluating this space should weight the audited, realised-value layers (YTL Power's segment profit, landowners' already-recognised gains, contractors' signed revenue) more heavily than the frequently-quoted headline pledge totals from hyperscalers, which remain fundamentally unverifiable with public information regardless of how large they sound. The newly-surfaced informal application moratorium (Notebook 3) is a genuinely important, underreported fact: it means Malaysia's regulators are already filtering this pipeline for real demand, not passively approving everything, a materially different risk picture than an unmanaged gold rush. The water and grid constraints documented in this project (Notebooks 10 and 11) are real and already producing concrete policy responses and at least one real community conflict, not distant hypothetical risks, and should be weighed as ongoing, active constraints on the pace of future build-out, not one-off issues already resolved.

# %% [markdown]
# ## Explain It Simply
#
# After tracing this whole boom from the land sales at the very start to the electricity actually being drawn today, the honest answer is: it's real, and it's still mostly a promise, at the same time, and this project's own numbers show exactly where each part of that split currently sits. The people and companies closest to physical, already-built assets, landowners, and the one company with fully audited data centre profits, YTL Power, have the most solid, provable gains today. The tech giants who make the biggest headlines with billion-dollar pledges are, ironically, the hardest part of this whole story to actually verify, because none of them has to publicly report how much of that pledged money has actually shown up. And a fact that changes how worried anyone should be about this being an unmanaged bubble: Malaysia's government has quietly been filtering out new non-AI data centre applications for about two years already, this isn't an unchecked stampede, it's a boom that's already being actively managed, even if nobody said so publicly until a parliamentary question forced it into the open.

# %% [markdown]
# ---
# **Sources**: This synthesis draws on all eleven prior notebooks in this project; no new primary sourcing is introduced here. The recommendation and limitations summary are this project's own, classified **DERIVED**.
